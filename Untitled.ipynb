# %% [markdown]
# # CORE: Applying Advanced Transformations
#
# The Task
# Your task is two-fold:
#
# # I. Clean the files and combine them into one final DataFrame.
#
# This dataframe should have the following columns:
# - Hero (Just the name of the Hero)
# - Publisher
# - Gender
# - Eye color
# - Race
# - Hair color
# - Height (numeric)
# - Skin color
# - Alignment
# - Weight (numeric)
#
# Plus, one-hot-encoded columns for every power that appears in the dataset. E.g.:
# - Agility
# - Flight
# - Superspeed
# - etc.
#     * Hint: There is a space in "100 kg" or "52.5 cm"

# %% [markdown]
# ## Imports

# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Importing the OS and JSON Modules
import os, json

# %% [markdown]
# ## Superhero Info DF

# %%
df1 = pd.read_csv('superhero_info - superhero_info.csv')
df1
# Out:
#                     Hero|Publisher  Gender               Race Alignment  \
# 0             A-Bomb|Marvel Comics    Male              Human      good
# 1     Abe Sapien|Dark Horse Comics    Male      Icthyo Sapien      good
# 2               Abin Sur|DC Comics    Male            Ungaran      good
# 3        Abomination|Marvel Comics    Male  Human / Radiation       bad
# 4      Absorbing Man|Marvel Comics    Male              Human       bad
# ..                             ...     ...                ...       ...
# 458     Yellowjacket|Marvel Comics    Male              Human      good
# 459  Yellowjacket II|Marvel Comics  Female              Human      good
# 460              Yoda|George Lucas    Male     Yoda's species      good
# 461              Zatanna|DC Comics  Female              Human      good
# 462                 Zoom|DC Comics    Male            Unknown       bad
#
#            Hair color Eye color Skin color  \
# 0             No Hair    yellow    Unknown
# 1             No Hair      blue       blue
# 2             No Hair      blue        red
# 3             No Hair     green    Unknown
# 4             No Hair      blue    Unknown
# ..                ...       ...        ...
# 458             Blond      blue    Unknown
# 459  Strawberry Blond      blue    Unknown
# 460             White     brown      green
# 461             Black      blue    Unknown
# 462             Brown       red    Unknown
#
#                                      Measurements
# 0    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1     {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2     {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4    {'Height': '193.0 cm', 'Weight': '122.0 kg'}
# ..                                            ...
# 458   {'Height': '183.0 cm', 'Weight': '83.0 kg'}
# 459   {'Height': '165.0 cm', 'Weight': '52.0 kg'}
# 460    {'Height': '66.0 cm', 'Weight': '17.0 kg'}
# 461   {'Height': '170.0 cm', 'Weight': '57.0 kg'}
# 462   {'Height': '185.0 cm', 'Weight': '81.0 kg'}
#
# [463 rows x 8 columns]

# %% [markdown]
# ### Hero|Publisher

# %%
df1[['Hero Name', 'Publisher']] = df1['Hero|Publisher'].str.split('|', expand = True)
df1 = df1.drop(columns = 'Hero|Publisher')
df1.sample(3)
# Out:
#      Gender     Race Alignment Hair color Eye color Skin color  \
# 207  Female  Unknown      good      Black      blue    Unknown
# 95     Male    Human      good      Black      blue    Unknown
# 162    Male    Human      good    Unknown   Unknown    Unknown
#
#                                     Measurements          Hero Name  Publisher
# 207  {'Height': '180.0 cm', 'Weight': '59.0 kg'}           Huntress  DC Comics
# 95   {'Height': '175.0 cm', 'Weight': '74.0 kg'}  Captain Marvel II  DC Comics
# 162  {'Height': '183.0 cm', 'Weight': '86.0 kg'}          Flash III  DC Comics

# %% [markdown]
# ### Measurements

# %%
#change single quotes on 'Measurements'
measurements = df1.loc[0,"Measurements"]
measurements = measurements.replace("'", '"')
#checking if the measurement is working
fixed_measurements = json.loads(measurements)
fixed_measurements
# Out:
# {'Height': '203.0 cm', 'Weight': '441.0 kg'}

# %%
df1['Measurements'] = df1['Measurements'].str.replace("'", '"')
df1['Measurements'] = df1['Measurements'].apply(json.loads)
df1['Measurements'].sample(3)
# Out:
# 107     {'Height': '226.0 cm', 'Weight': '70.0 kg'}
# 230    {'Height': '287.0 cm', 'Weight': '855.0 kg'}
# 364     {'Height': '178.0 cm', 'Weight': '79.0 kg'}
# Name: Measurements, dtype: object

# %%
height_weight = df1['Measurements'].apply(pd.Series)
height_weight.sample(3)
# Out:
#        Height   Weight
# 311  157.0 cm  79.0 kg
# 321  183.0 cm  86.0 kg
# 91   193.0 cm  90.0 kg

# %%
df1 = pd.concat((df1, height_weight), axis = 1)
df1 = df1.drop(columns = 'Measurements')
df1.sample(3)
# Out:
#      Gender        Race Alignment Hair color Eye color Skin color  \
# 298  Female   Luphomoid       bad    No Hair      blue       blue
# 365    Male     Unknown      good        Red     brown    Unknown
# 235    Male  Bolovaxian      good    No Hair       red       pink
#
#        Hero Name      Publisher    Height    Weight
# 298       Nebula  Marvel Comics  185.0 cm   83.0 kg
# 365  Shatterstar  Marvel Comics  191.0 cm   88.0 kg
# 235      Kilowog      DC Comics  234.0 cm  324.0 kg

# %%
df1.columns
# Out:
# Index(['Gender', 'Race', 'Alignment', 'Hair color', 'Eye color', 'Skin color',
#        'Hero Name', 'Publisher', 'Height', 'Weight'],
#       dtype='object')

# %%
df1 = df1[['Hero Name', 'Publisher', 'Gender', 'Race', 'Height', 'Weight', 
         'Alignment', 'Hair color', 'Eye color', 'Skin color']]
df1
# Out:
#            Hero Name          Publisher  Gender               Race    Height  \
# 0             A-Bomb      Marvel Comics    Male              Human  203.0 cm
# 1         Abe Sapien  Dark Horse Comics    Male      Icthyo Sapien  191.0 cm
# 2           Abin Sur          DC Comics    Male            Ungaran  185.0 cm
# 3        Abomination      Marvel Comics    Male  Human / Radiation  203.0 cm
# 4      Absorbing Man      Marvel Comics    Male              Human  193.0 cm
# ..               ...                ...     ...                ...       ...
# 458     Yellowjacket      Marvel Comics    Male              Human  183.0 cm
# 459  Yellowjacket II      Marvel Comics  Female              Human  165.0 cm
# 460             Yoda       George Lucas    Male     Yoda's species   66.0 cm
# 461          Zatanna          DC Comics  Female              Human  170.0 cm
# 462             Zoom          DC Comics    Male            Unknown  185.0 cm
#
#        Weight Alignment        Hair color Eye color Skin color
# 0    441.0 kg      good           No Hair    yellow    Unknown
# 1     65.0 kg      good           No Hair      blue       blue
# 2     90.0 kg      good           No Hair      blue        red
# 3    441.0 kg       bad           No Hair     green    Unknown
# 4    122.0 kg       bad           No Hair      blue    Unknown
# ..        ...       ...               ...       ...        ...
# 458   83.0 kg      good             Blond      blue    Unknown
# 459   52.0 kg      good  Strawberry Blond      blue    Unknown
# 460   17.0 kg      good             White     brown      green
# 461   57.0 kg      good             Black      blue    Unknown
# 462   81.0 kg       bad             Brown       red    Unknown
#
# [463 rows x 10 columns]

# %% [markdown]
# ## Superhero Powers DF
# ### Powers

# %%
df2 = pd.read_csv('superhero_powers - superhero_powers.csv')
df2
# Out:
#           hero_names                                             Powers
# 0            3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1             A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2         Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3           Abin Sur                                 Lantern Power Ring
# 4        Abomination  Accelerated Healing,Intelligence,Super Strengt...
# ..               ...                                                ...
# 662  Yellowjacket II                 Flight,Energy Blasts,Size Changing
# 663             Ymir  Cold Resistance,Durability,Longevity,Super Str...
# 664             Yoda  Agility,Stealth,Danger Sense,Marksmanship,Weap...
# 665          Zatanna  Cryokinesis,Telepathy,Magic,Fire Control,Proba...
# 666             Zoom  Super Speed,Intangibility,Time Travel,Time Man...
#
# [667 rows x 2 columns]

# %%
powers = df2.loc[2,'Powers']
powers
# Out:
# 'Agility,Accelerated Healing,Cold Resistance,Durability,Underwater breathing,Marksmanship,Weapons Master,Longevity,Intelligence,Super Strength,Telepathy,Stamina,Immortality,Reflexes,Enhanced Sight,Sub-Mariner'

# %%
df2['Power split'] = df2['Powers'].str.split(',', expand = False)
df2['Power split']
# Out:
# 0        [Agility, Super Strength, Stamina, Super Speed]
# 1      [Accelerated Healing, Durability, Longevity, S...
# 2      [Agility, Accelerated Healing, Cold Resistance...
# 3                                   [Lantern Power Ring]
# 4      [Accelerated Healing, Intelligence, Super Stre...
#                              ...
# 662               [Flight, Energy Blasts, Size Changing]
# 663    [Cold Resistance, Durability, Longevity, Super...
# 664    [Agility, Stealth, Danger Sense, Marksmanship,...
# 665    [Cryokinesis, Telepathy, Magic, Fire Control, ...
# 666    [Super Speed, Intangibility, Time Travel, Time...
# Name: Power split, Length: 667, dtype: object

# %%
exploaded = df2.explode('Power split')
exploaded
# Out:
#     hero_names                                             Powers  \
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# ..         ...                                                ...
# 665    Zatanna  Cryokinesis,Telepathy,Magic,Fire Control,Proba...
# 666       Zoom  Super Speed,Intangibility,Time Travel,Time Man...
# 666       Zoom  Super Speed,Intangibility,Time Travel,Time Man...
# 666       Zoom  Super Speed,Intangibility,Time Travel,Time Man...
# 666       Zoom  Super Speed,Intangibility,Time Travel,Time Man...
#
#              Power split
# 0                Agility
# 0         Super Strength
# 0                Stamina
# 0            Super Speed
# 1    Accelerated Healing
# ..                   ...
# 665      Weather Control
# 666          Super Speed
# 666        Intangibility
# 666          Time Travel
# 666    Time Manipulation
#
# [5874 rows x 3 columns]

# %%
# using drop.na so we won't have NAN in our list
cols_to_make = exploaded['Power split'].dropna().unique()
cols_to_make
# Out:
# array(['Agility', 'Super Strength', 'Stamina', 'Super Speed',
#        'Accelerated Healing', 'Durability', 'Longevity', 'Camouflage',
#        'Self-Sustenance', 'Cold Resistance', 'Underwater breathing',
#        'Marksmanship', 'Weapons Master', 'Intelligence', 'Telepathy',
#        'Immortality', 'Reflexes', 'Enhanced Sight', 'Sub-Mariner',
#        'Lantern Power Ring', 'Invulnerability', 'Animation',
#        'Super Breath', 'Dimensional Awareness', 'Flight', 'Size Changing',
#        'Teleportation', 'Magic', 'Dimensional Travel',
#        'Molecular Manipulation', 'Energy Manipulation', 'Power Cosmic',
#        'Energy Absorption', 'Elemental Transmogrification',
#        'Fire Resistance', 'Natural Armor', 'Heat Resistance',
#        'Matter Absorption', 'Regeneration', 'Stealth', 'Power Suit',
#        'Energy Blasts', 'Energy Beams', 'Heat Generation', 'Danger Sense',
#        'Phasing', 'Force Fields', 'Hypnokinesis', 'Invisibility',
#        'Enhanced Senses', 'Jump', 'Shapeshifting', 'Elasticity',
#        'Substance Secretion', 'Enhanced Hearing', 'Adaptation', 'Gliding',
#        'Natural Weapons', 'Wallcrawling', 'Vision - Thermal',
#        'Power Augmentation', 'Cryokinesis', 'Duplication',
#        'Weapon-based Powers', 'Fire Control', 'Enhanced Memory',
#        'Energy Constructs', 'Power Absorption', 'Time Travel',
#        'Enhanced Smell', 'Water Control', 'Vision - Telescopic',
#        'Magnetism', 'Vision - Microscopic', 'Vision - Night',
#        'Vision - Heat', 'Vision - X-Ray', 'Psionic Powers',
#        'Toxin and Disease Resistance', 'Animal Attributes',
#        'Animal Oriented Powers', 'Toxin and Disease Control', 'Empathy',
#        'Animal Control', 'Darkforce Manipulation', 'Time Manipulation',
#        'Reality Warping', 'Web Creation', 'Symbiote Costume',
#        'Telekinesis', 'Levitation', 'Biokinesis', 'Sonar',
#        'Enhanced Touch', 'Seismic Power', 'Energy Armor',
#        'Omnilingualism', 'Radiation Immunity', 'Density Control',
#        'Light Control', 'Illumination', 'Molecular Combustion',
#        'Astral Travel', 'Precognition', 'Intangibility', 'Illusions',
#        'Audio Control', 'Sonic Scream', 'Peak Human Condition',
#        'Vision - Infrared', 'Dexterity', 'Omnitrix', 'Omnipotent',
#        'Possession', 'Energy Resistance', 'Vision - Cryo', 'Mind Control',
#        'Mind Blast', 'Clairvoyance', 'Probability Manipulation',
#        'Death Touch', 'Electrokinesis', 'Gravity Control',
#        'Technopath/Cyberpath', 'Radar Sense', 'Astral Projection',
#        'Cloaking', 'Telepathy Resistance', 'Mind Control Resistance',
#        'Hyperkinesis', 'Spatial Awareness', 'Radiation Control',
#        'Radiation Absorption', 'Magic Resistance', 'Element Control',
#        'Plant Control', 'Terrakinesis', 'Power Sense', 'Wind Control',
#        'Qwardian Power Ring', 'Echolocation', 'Resurrection', 'The Force',
#        'Summoning', 'Banish', 'Molecular Dissipation',
#        'Electrical Transport', 'Speed Force', 'Grim Reaping',
#        'Portal Creation', 'Vitakinesis', 'Projection', 'Insanity',
#        'Photographic Reflexes', 'Anti-Gravity', 'Thirstokinesis',
#        'Power Nullifier', 'Weather Control', 'Omnipresent', 'Omniscient',
#        'Hair Manipulation', 'Nova Force', 'Odin Force', 'Phoenix Force',
#        'Intuitive aptitude', 'Melting', 'Changing Armor'], dtype=object)

# %%
for col in cols_to_make:
    df2[col] = df2['Powers'].str.contains(col)
df2.sample(3)
# Out:
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# C:\Users\j29ma\AppData\Local\Temp\ipykernel_13308\869094845.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
#     hero_names                                             Powers  \
# 155    Chromos  Agility,Super Strength,Energy Blasts,Stamina,T...
# 392   Mandarin  Weapons Master,Intelligence,Cryokinesis,Energy...
# 450       Nova  Agility,Accelerated Healing,Durability,Energy ...
#
#                                            Power split  Agility  \
# 155  [Agility, Super Strength, Energy Blasts, Stami...     True
# 392  [Weapons Master, Intelligence, Cryokinesis, En...    False
# 450  [Agility, Accelerated Healing, Durability, Ene...     True
#
#      Super Strength  Stamina  Super Speed  Accelerated Healing  Durability  \
# 155            True     True        False                False       False
# 392           False    False        False                False       False
# 450            True     True         True                 True        True
#
#      Longevity  ...  Weather Control  Omnipresent  Omniscient  \
# 155      False  ...            False        False       False
# 392      False  ...            False        False       False
# 450      False  ...            False        False       False
#
#      Hair Manipulation  Nova Force  Odin Force  Phoenix Force  \
# 155              False       False       False          False
# 392              False       False       False          False
# 450              False        True       False          False
#
#      Intuitive aptitude  Melting  Changing Armor
# 155               False    False           False
# 392               False    False           False
# 450               False    False           False
#
# [3 rows x 170 columns]

# %%
df2 = df2.drop(columns = ['Powers', 'Power split', 'Power split'])
df2.sample(3)
# Out:
#         hero_names  Agility  Super Strength  Stamina  Super Speed  \
# 194      Destroyer    False            True    False        False
# 342       Kevin 11     True            True     True         True
# 69   Beta Ray Bill    False            True     True         True
#
#      Accelerated Healing  Durability  Longevity  Camouflage  Self-Sustenance  \
# 194                False       False      False       False            False
# 342                 True       False      False       False            False
# 69                  True       False      False       False            False
#
#      ...  Weather Control  Omnipresent  Omniscient  Hair Manipulation  \
# 194  ...            False        False       False              False
# 342  ...            False        False       False              False
# 69   ...            False        False       False              False
#
#      Nova Force  Odin Force  Phoenix Force  Intuitive aptitude  Melting  \
# 194       False       False          False               False    False
# 342       False       False          False               False    False
# 69        False       False          False               False    False
#
#      Changing Armor
# 194           False
# 342           False
# 69            False
#
# [3 rows x 168 columns]

# %% [markdown]
# ## Merging Two Dataframes

# %%
df = pd.concat([df1, df2], axis = 1, join = 'inner')
display(df)
# Out:
#            Hero Name          Publisher  Gender               Race    Height  \
# 0             A-Bomb      Marvel Comics    Male              Human  203.0 cm
# 1         Abe Sapien  Dark Horse Comics    Male      Icthyo Sapien  191.0 cm
# 2           Abin Sur          DC Comics    Male            Ungaran  185.0 cm
# 3        Abomination      Marvel Comics    Male  Human / Radiation  203.0 cm
# 4      Absorbing Man      Marvel Comics    Male              Human  193.0 cm
# ..               ...                ...     ...                ...       ...
# 458     Yellowjacket      Marvel Comics    Male              Human  183.0 cm
# 459  Yellowjacket II      Marvel Comics  Female              Human  165.0 cm
# 460             Yoda       George Lucas    Male     Yoda's species   66.0 cm
# 461          Zatanna          DC Comics  Female              Human  170.0 cm
# 462             Zoom          DC Comics    Male            Unknown  185.0 cm
#
#        Weight Alignment        Hair color Eye color Skin color  ...  \
# 0    441.0 kg      good           No Hair    yellow    Unknown  ...
# 1     65.0 kg      good           No Hair      blue       blue  ...
# 2     90.0 kg      good           No Hair      blue        red  ...
# 3    441.0 kg       bad           No Hair     green    Unknown  ...
# 4    122.0 kg       bad           No Hair      blue    Unknown  ...
# ..        ...       ...               ...       ...        ...  ...
# 458   83.0 kg      good             Blond      blue    Unknown  ...
# 459   52.0 kg      good  Strawberry Blond      blue    Unknown  ...
# 460   17.0 kg      good             White     brown      green  ...
# 461   57.0 kg      good             Black      blue    Unknown  ...
# 462   81.0 kg       bad             Brown       red    Unknown  ...
#
#     Weather Control  Omnipresent  Omniscient  Hair Manipulation  Nova Force  \
# 0             False        False       False              False       False
# 1             False        False       False              False       False
# 2             False        False       False              False       False
# 3             False        False       False              False       False
# 4             False        False       False              False       False
# ..              ...          ...         ...                ...         ...
# 458           False        False       False              False       False
# 459           False        False       False              False       False
# 460           False        False       False              False       False
# 461           False        False       False              False       False
# 462           False        False       False              False       False
#
#      Odin Force  Phoenix Force  Intuitive aptitude  Melting  Changing Armor
# 0         False          False               False    False           False
# 1         False          False               False    False           False
# 2         False          False               False    False           False
# 3         False          False               False    False           False
# 4         False          False               False    False           False
# ..          ...            ...                 ...      ...             ...
# 458       False          False               False    False           False
# 459       False          False               False    False           False
# 460       False          False               False    False           False
# 461       False          False               False    False           False
# 462       False          False               False    False           False
#
# [463 rows x 178 columns]

# %% [markdown]
# # II. Use your combined DataFrame to answer the following questions.
#
# 1. Compare the average weight of super powers who have Super Speed to those who do not.
# 2. What is the average height of heroes for each publisher?

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Columns: 178 entries, Hero Name to Changing Armor
# dtypes: bool(167), object(11)
# memory usage: 115.4+ KB
#        Hero Name          Publisher Gender               Race    Height  \
# 0         A-Bomb      Marvel Comics   Male              Human  203.0 cm
# 1     Abe Sapien  Dark Horse Comics   Male      Icthyo Sapien  191.0 cm
# 2       Abin Sur          DC Comics   Male            Ungaran  185.0 cm
# 3    Abomination      Marvel Comics   Male  Human / Radiation  203.0 cm
# 4  Absorbing Man      Marvel Comics   Male              Human  193.0 cm
#
#      Weight Alignment Hair color Eye color Skin color  ... Weather Control  \
# 0  441.0 kg      good    No Hair    yellow    Unknown  ...           False
# 1   65.0 kg      good    No Hair      blue       blue  ...           False
# 2   90.0 kg      good    No Hair      blue        red  ...           False
# 3  441.0 kg       bad    No Hair     green    Unknown  ...           False
# 4  122.0 kg       bad    No Hair      blue    Unknown  ...           False
#
#    Omnipresent  Omniscient  Hair Manipulation  Nova Force  Odin Force  \
# 0        False       False              False       False       False
# 1        False       False              False       False       False
# 2        False       False              False       False       False
# 3        False       False              False       False       False
# 4        False       False              False       False       False
#
#    Phoenix Force  Intuitive aptitude  Melting  Changing Armor
# 0          False               False    False           False
# 1          False               False    False           False
# 2          False               False    False           False
# 3          False               False    False           False
# 4          False               False    False           False
#
# [5 rows x 178 columns]
